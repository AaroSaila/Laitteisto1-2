# %% [markdown]
# # Assignment 2. Heart rate detection
# Hardware 1 - Orientation to Health Technology<br>
# Your name: **Aaro Säilä**<br>
# Date returned: **24.01.2024**<br>
# Metropolia University of Applied Sciences<br>

# %% [markdown]
# ## 1. Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
import heartpy as hp

# %% [markdown]
# ## 2. All data
# Read in and plot all data.

# %%
data = hp.get_data("capture01_250Hz.txt")
Fs = 250
time = np.arange(len(data))/Fs

plt.figure(figsize=(12, 4))
plt.plot(time, data)
plt.grid()
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (uint16)")
plt.show()

# %% [markdown]
# ## 3. Selected segment
# Select a **60 seconds** segment from the data and make a graph of it.

# %%
np.random.seed(8612)
t0 = np.random.randint(30, 100)
print(f"Segment starts from: {t0} s")

i = (t0 < time) & (time < t0 + 60)
data2 = data[i]
time2 = time[i]

plt.figure(figsize=(12, 4))
plt.plot(time2, data2)
plt.grid()
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (uint16)")
plt.show()
# Out:
# Segment starts from: 68 s

# %% [markdown]
# ## 4. Peak detection and HRV measurements
# Detect the peaks from the selected segment of data, make a graph of the processed data segment to show the peaks, and finally display the measures computed.

# %%
plt.figure(figsize=(12,4))
plt.plot(time2, data2)
plt.grid()
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (uint16)")
plt.xlim(t0, t0 + 6)
plt.show()

# %%
wd, m = hp.process(data, sample_rate=250.0)
plt.figure(figsize=(12, 4))
hp.plotter(wd, m)
for measure in m.keys():
    print("%s: %f" %(measure, m[measure]))
# Out:
# bpm: 67.420266
# ibi: 889.940120
# sdnn: 41.688566
# sdsd: 30.824430
# rmssd: 38.945613
# pnn20: 0.331288
# pnn50: 0.141104
# hr_mad: 24.000000
# sd1: 27.538510
# sd2: 47.626648
# s: 4120.409032
# sd1/sd2: 0.578216
# breathingrate: 0.233333
# /home/aaro/Documents/Code/Metropolia/Laitteisto1-2/venv/lib/python3.11/site-packages/heartpy/visualizeutils.py:119: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ## 5. Interpretations
# Interpret the results.

# %% [markdown]
# **(DOUBLE CLICK AND)** Write your interpretations of the results here ...
#
# 1. ~67 per minute. Low.
# 2. ~890. Low/average.
# 3. ~42. SDNN because it measures the variation in inter-beat-intervals. The value is average or slightly high.
# 4. The person is in recovery.
